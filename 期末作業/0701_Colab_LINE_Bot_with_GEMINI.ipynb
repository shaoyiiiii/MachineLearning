# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 10.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://reawake-brilliant-favorable.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://reawake-brilliant-favorable.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# AI Agent（人工智慧代理）是一個能夠**感知**其環境、進行**推理**、做出**決策**並**採取行動**以達成特定目標的智慧系統或軟體實體。你可以把它想像成一個擁有「智慧大腦」和「手腳」的自動化助手。
#
# ### AI Agent 的核心組成部分（工作原理）
#
# 一個 AI Agent 的運作通常涉及以下循環：
#
# 1.  **感知 (Perception)**：Agent 透過各種「感測器」或輸入介面來接收環境中的資訊。
#     *   **例子**：感測器數據（攝像頭、麥克風、雷達）、API 調用、數據庫查詢、用戶輸入、文本訊息、網頁內容等。
#
# 2.  **推理/決策 (Reasoning/Decision-making)**：Agent 根據感知到的資訊，利用其內部的智慧模型（如 AI 演算法、規則集、邏輯推理、機器學習模型，特別是大型語言模型LLMs）來分析、理解當前狀態，並規劃下一步行動。
#     *   **例子**：判斷當前情況、預測未來狀態、計算最佳路徑、選擇合適的工具或技能、制定執行計劃。
#
# 3.  **行動 (Action)**：Agent 透過「執行器」或輸出介面來影響或改變環境。
#     *   **例子**：物理動作（移動機器人手臂、駕駛汽車）、發送指令（操作軟體、修改數據）、產生文本或語音回應、發送電子郵件、執行程式碼等。
#
# 4.  **環境 (Environment)**：Agent 所處並能與之互動的場景。可以是物理世界（如工廠、道路），也可以是數位世界（如網際網路、操作系統、應用程式）。
#
# ### AI Agent 的主要特點
#
# *   **目標導向 (Goal-Oriented)**：它們被設計來實現特定的目標或任務。
# *   **自主性 (Autonomy)**：在沒有人類持續監督的情況下，能夠獨立運作。
# *   **反應性 (Reactivity)**：能夠對環境的變化做出即時反應。
# *   **主動性 (Proactivity)**：不僅對環境變化做出反應，還能主動採取行動以追求目標。
# *   **學習能力 (Learning Capability)**：許多 Agent 能夠從經驗中學習，改進其性能和決策能力（並非所有 Agent 都具備此能力）。
#
# ### AI Agent 的類型與例子
#
# AI Agent 可以是純軟體的，也可以是結合硬體的：
#
# **1. 軟體 Agent (Software Agents)**
#
# *   **個人助理**：Siri, Google Assistant, Alexa 等，它們感知語音命令，理解意圖，並執行如設定鬧鐘、查詢天氣、發送訊息等動作。
# *   **客服聊天機器人 (Chatbots)**：感知用戶文本輸入，理解問題，並提供回答或執行預設操作（如查詢訂單、轉接人工服務）。
# *   **推薦系統**：感知用戶的瀏覽和購買歷史，推理出用戶偏好，並推薦相關商品或內容。
# *   **自動化交易系統**：感知市場數據，分析趨勢，自動執行股票或加密貨幣的買賣。
# *   **網絡爬蟲 (Web Crawlers)**：感知網頁結構和內容，從網際網路收集資訊。
# *   **現代基於大型語言模型 (LLM) 的 Agent**：這是當前最熱門的發展方向。LLM 充當了 Agent 的「大腦」，負責理解、規劃和推理。這些 Agent 可以：
#     *   根據用戶需求，自動撰寫程式碼、調用工具、搜索資料、生成報告。
#     *   與多個應用程式互動，自動完成複雜的工作流程（例如，訂機票、預訂餐廳）。
#
# **2. 物理 Agent (Physical Agents)**
#
# *   **自動駕駛汽車**：感知道路狀況、交通標誌、行人，推理出最佳行駛路徑和速度，並執行加速、剎車、轉向等動作。
# *   **工業機器人**：感知生產線上的物品位置和狀態，執行組裝、搬運、焊接等任務。
# *   **無人機 (Drones)**：感知環境（高度、障礙物），規劃飛行路徑，執行偵查、送貨等任務。
#
# ### AI Agent 的發展趨勢
#
# 隨著大型語言模型（LLMs）的興起，AI Agent 的能力得到了極大的提升。LLMs 為 Agent 提供了強大的**規劃、推理和工具使用**能力，使得 Agent 不再僅限於預設的規則，而是能：
#
# 1.  **理解複雜的、開放式的任務指令。**
# 2.  **將複雜任務分解為更小的子任務。**
# 3.  **自主選擇並使用外部工具（API、網絡搜索、程式碼解釋器）來執行子任務。**
# 4.  **從執行結果中學習和調整其計劃。**
#
# 總之，AI Agent 是將人工智慧從單純的數據分析或模式識別，推進到能夠自主地與世界（無論是數位還是物理）互動並達成目標的實體，是實現通用人工智慧的重要一步。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Ming Hsin University of Science and Technology, MHUST）位於台灣新竹縣新豐鄉，是一所歷史悠久、以培養實用型專業人才為導向的私立科技大學。
#
# 以下是明新科技大學的簡要介紹：
#
# 1.  **創校歷史與沿革：** 學校創立於1966年，前身為「明新工業專科學校」，後於2001年改制為科技大學，並持續發展至今。從專科學校轉型為科技大學，反映了其在技職教育領域的深耕與發展。
#
# 2.  **地理位置優勢：** 明新科大地理位置優越，鄰近台灣的科技重鎮—新竹科學園區，以及周邊多個工業區。這使得學校在產學合作、學生實習與就業方面，具有得天獨厚的條件。
#
# 3.  **教育理念與特色：**
#     *   **校訓：** 「明德、創新、卓越」。
#     *   **務實致用：** 學校秉持技職教育務實致用的精神，致力於培養具備專業技能、實作能力與創新思維的產業人才。
#     *   **產學合作：** 與業界保持緊密連結，推動多元的產學合作計畫，確保課程內容與產業需求同步，提供學生豐富的實習與工讀機會。
#     *   **多元學習：** 注重學生跨領域能力的培養，鼓勵學生考取專業證照、參與專題製作與國際交流活動，提升職場競爭力。
#
# 4.  **學院與系所：** 學校設有工學院、管理學院、服務產業學院等，提供涵蓋工程技術、資訊通訊、商業管理、設計、觀光餐旅等多元領域的學士班、碩士班課程。
#
# 5.  **畢業生表現：** 明新科大畢業生因其紮實的專業技能和良好的實務經驗，在就業市場上廣受歡迎，尤其在科技、製造與服務產業有著不錯的表現。
#
# 總體而言，明新科技大學是一所積極回應社會與產業變遷，持續創新教育模式，並為台灣社會與經濟發展貢獻專業人才的重要學府。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"Uecb5c0e1eef83517d8d70393a19967b3","events":[{"type":"message","message":{"type":"text","id":"616043485073769118","quoteToken":"1mxajo6DW3064iZch1i9gY0d_EG-FjLEZu6vewlh1TGoa63N8duTODAbNDjsu9ZWS3XYh9xdWPAD4bUdWz3jeEHC30xj1nz6eIZtjeuRhcgQuZYRUzjsxGD9nCC-gG9P6saELgj7o69eYdZzmlH4xQ","markAsReadToken":"otJRAPKWbRkqHEouSKlcohDbcJ-uuLctGMouJO5EiJ3A7xM1kgJ